# %%
from GenerateAxisRoster import GenerateAxisRoster

# %% [markdown]
# # Madden Attributes to Axis Attributes Links
# https://steamcommunity.com/app/932980/discussions/0/1739968490571334749/
#
# https://madden.fandom.com/wiki/Attributes

# %% [markdown]
# # Axis Roster Information
#
# An Axis Roster must have exactly $53$ players in total.
#
# Rosters must first have a total of $30$ starters IN THE FOLLOWING ORDER:
# * QB 1
# * RBs 1-2
# * WRs 1-5
# * TE 1
# * LT 1
# * LG 1
# * C 1
# * RG 1
# * RT 1
# * LE 1, DTs 1-2, RE 1 (Total of 4 DLs; distribution may vary depending on team)
# * LOLB 1, MLBs 1-2, ROLB 1 (Total of 4 LBs; distribution may vary depending on team)
# * LCB 1, LCB 2, SS 1, FS 1, RCB 1, RCB 2 (Total of 6 DBs; distribution may vary depending on team)
# * K 1
# * P 1
#
# Rosters must then have $23$ unused players as backups.

# %%
team='New York Jets'
GenerateAxisRoster(team)

# %%
GenerateAxisRoster(team).axis_roster_df.head(30) # Sample Rows of Old Axis Roster to Be Updated
# Out:
#     INDEX        FIRST        LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  SPEED  \
# 0       0          Sam     Darnold     1      14      75     225  QB     78
# 1       1      Le'Veon        Bell     5      26      73     225  RB     87
# 2       2        Frank        Gore     5      23      69     212  RB     83
# 3       3      Jamison     Crowder     5      82      69     177  WR     90
# 4       4       Quincy      Enunwa     1      81      74     225  WR     89
# 5       5      Breshad    Perriman     5      19      74     215  WR     94
# 6       6         Josh     Bellamy     5      15      72     211  WR     88
# 7       7         Josh     Doctson     5      18      74     206  WR     88
# 8       8  Christopher     Herndon     1      89      76     253  TE     80
# 9       9        Mekhi      Becton     1      77      79     364  OL     69
# 10     10         Alex       Lewis     1      71      78     305  OL     64
# ...

# %%
GenerateAxisRoster(team).madden_roster_df.head() # Sample Rows of Madden Roster To Be Used for Updating
# Out:
#             Full Name  Overall Rating Position  Age  Speed  Acceleration  \
# 0     Connor McGovern              74        C   27     68            83
# 1  Jonotthan Harrison              67        C   29     65            76
# 2        James Murray              55        C   25     67            75
# 3        Pierre Desir              80       CB   29     88            93
# 4         Brian Poole              79       CB   27     90            92
#
#    Awareness  Agility  Strength  Throw Power  ...  Jersey Number  \
# 0         82       70        87           21  ...             60
# 1         82       57        87           30  ...             78
# 2         59       60        82           30  ...             61
# 3         81       88        65           35  ...             35
# 4         83       86        68           18  ...             34
#
#    Total Salary  Signing Bonus  Archetype           Running Style  Years Pro  \
# ...

# %%
GenerateAxisRoster(team).new_axis_roster_df.head(30) # New Axis Starting Roster After Modifcation
# Out:
#     INDEX        FIRST        LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  SPEED  \
# 0       0          Sam     Darnold     1      14      75     225  QB     78
# 1       1      Le'Veon        Bell     5      26      73     225  RB     87
# 2       2        Frank        Gore     5      23      69     212  RB     83
# 3       3      Jamison     Crowder     5      82      69     177  WR     90
# 4       4       Quincy      Enunwa     1      81      74     225  WR     89
# 5       5      Breshad    Perriman     5      19      74     215  WR     94
# 6       6         Josh     Bellamy     5      15      72     211  WR     88
# 7       7         Josh     Doctson     5      18      74     206  WR     88
# 8       8  Christopher     Herndon     1      89      76     253  TE     80
# 9       9        Mekhi      Becton     1      77      79     364  OL     69
# 10     10         Alex       Lewis     1      71      78     305  OL     64
# ...

# %%
GenerateAxisRoster(team).new_axis_roster_df.iloc[30:] # New Axis Starting Roster Backups After Modifcation
# Out:
#     INDEX      FIRST        LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  SPEED  \
# 30     30        Joe      Flacco     5       5      78     245  QB     72
# 31     31      James      Morgan     5       4      76     229  QB     74
# 32     32      David       Fales     1       3      74     213  QB     72
# 33     33       Josh       Adams     5      36      74     225  RB     89
# 34     34    Trenton      Cannon     5      25      71     185  RB     92
# 35     35     Denzel        Mims     1      11      75     207  WR     92
# 36     36    Braxton     Berrios     5      10      69     186  WR     91
# 37     37       Ryan     Griffin     5      84      78     255  TE     73
# 38     38     Trevon       Wesco     5      85      75     268  TE     76
# 39     39      Conor   McDermott     1      69      80     305  OL     67
# 40     40    Cameron       Clark     3      72      76     308  OL     63
# 41     41  Jonotthan    Harrison     5      78      76     300  OL     65
# ...

# %% [markdown]
# Call GenerateAxisRoster all $32$ teams and update the 'Team Mods' folder in the Axis Football 2020 local file directory.
