# %% [markdown]
# # Axis Football 2021 Roster Mods
#
# In this notebook, we replace the current football rosters in the game Axis Football 2021 with the rosters from the Madden NFL 22 database from https://www.ea.com/games/madden-nfl/player-ratings.

# %%
from RosterGenerator import *
week_num = 17 # Update this number at the end of each week during the NFL season

try:
    # !rm -r "Madden Rosters"
except:
    pass

# %% [markdown]
# ## Obtaining NFL Teams
#
# In the code cell below, we print the names of all the $32$ NFL teams.

# %%
with open('Madden_Team_IDs.json', 'r') as f:
    madden_IDs_dict = json.load(f)
    NFL_team_names = list(madden_IDs_dict.keys())
print(NFL_team_names)
# Out:
# ['Chicago Bears', 'Cincinnati Bengals', 'Buffalo Bills', 'Denver Broncos', 'Cleveland Browns', 'Tampa Bay Buccaneers', 'Arizona Cardinals', 'Los Angeles Chargers', 'Kansas City Chiefs', 'Indianapolis Colts', 'Dallas Cowboys', 'Miami Dolphins', 'Philadelphia Eagles', 'Atlanta Falcons', 'San Francisco 49ers', 'New York Giants', 'Jacksonville Jaguars', 'New York Jets', 'Detroit Lions', 'Green Bay Packers', 'Carolina Panthers', 'New England Patriots', 'Las Vegas Raiders', 'Los Angeles Rams', 'Baltimore Ravens', 'Washington Football Team', 'New Orleans Saints', 'Seattle Seahawks', 'Pittsburgh Steelers', 'Tennessee Titans', 'Minnesota Vikings', 'Houston Texans']

# %% [markdown]
# ## Loading An NFL Team's Current Madden NFL Roster
#
# In the code cell below, we obtain an NFL team's current Madden NFL Roster from the aforementioned database. $\textbf{Note}:$ The database is updated during the NFL season on a weekly basis.

# %%
team_name='New York Jets'
RosterGenerator(team_name,week_num).madden_roster_df
# Out:
#    firstName   lastName position  jerseyNum  age  height  weight  \
# 0    Quinnen   Williams       DT         95   23      75     303
# 1     Marcus       Maye       SS         20   28      72     207
# 2       Carl     Lawson       RE         58   26      74     261
# 3      Mekhi     Becton       LT         77   22      79     364
# 4       C.J.     Mosley     LOLB         57   29      74     231
# ..       ...        ...      ...        ...  ...     ...     ...
# 64     Javin      White     ROLB          9   24      74     211
# 65    Rachad  Wildgoose       CB         29   21      70     191
# 66     Conor  McDermott       LT         69   28      80     310
# 67      Mike      White       QB          5   26      77     218
# 68    Thomas   Hennessy       TE         42   27      74     246
#
#     overall_rating  awareness_rating  strength_rating  ...  \
# 0               86                89               89  ...
# 1               85                87               77  ...
# 2               83                80               88  ...
# 3               82                89               94  ...
# 4               81                81               75  ...
# ..             ...               ...              ...  ...
# 64              62                57               65  ...
# 65              62                60               54  ...
# 66              56                64               84  ...
# 67              55                63               54  ...
# 68              31                60               67  ...
#
#     passBlockPower_rating  impactBlocking_rating  carrying_rating  \
# 0                      44                     89               39
# 1                      35                     71               65
# 2                      45                     79               27
# 3                      82                     99               40
# 4                      45                     87               66
# ..                    ...                    ...              ...
# 64                     35                     55               55
# 65                     35                     47               53
# 66                     65                     73               21
# 67                     18                     20               57
# 68                     50                     72               63
#
#     breakTackle_rating  passBlock_rating  changeOfDirection_rating  \
# 0                   16                44                        61
# 1                   42                35                        83
# 2                   31                45                        66
# 3                   25                79                        55
# 4                   32                45                        73
# ..                 ...               ...                       ...
# 64                  38                30                        81
# 65                  40                35                        85
# 66                   6                63                        51
# 67                  22                19                        72
# 68                  15                59                        70
#
#     press_rating  throwAccuracyDeep_rating runBlockFinesse_rating  \
# 0             14                         6                     45
# 1             66                        10                     35
# 2             30                         6                     45
# 3             10                         6                     85
# 4             49                         6                     45
# ..           ...                       ...                    ...
# 64            62                         6                     35
# 65            70                         6                     35
# 66            10                         6                     64
# 67            10                        64                     18
# 68            15                         6                     35
#
#     agility_rating
# 0               79
# 1               86
# 2               82
# 3               59
# 4               87
# ..             ...
# 64              84
# 65              81
# 66              66
# 67              71
# 68              71
#
# [69 rows x 62 columns]

# %% [markdown]
# ## Loading An NFL Team's Initial Axis Football Roster
#
# In the code cell below, we obtain an NFL team's initial, outdated Axis Football roster which we intend to update.

# %%
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_df
# Out:
#     INDEX      FIRST          LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  SPEED  \
# 0       0       Luke          Falk     1       8      76     223  QB     86
# 1       1    Le'Veon          Bell     5      26      74     218  RB     96
# 2       2         Ty    Montgomery     5      88      70     204  RB     86
# 3       3    Jamison       Crowder     5      82      76     230  WR     84
# 4       4  Demaryius        Thomas     1      88      75     214  WR     82
# 5       5     Quincy        Enunwa     5      81      69     224  WR     86
# 6       6      Robby      Anderson     5      11      74     225  WR     90
# 7       7       Josh       Bellamy     5      15      66     195  WR     86
# 8       8       Ryan       Griffin     1      84      77     265  TE     85
# 9       9     Kelvin       Beachum     1      68      78     315  OL     62
# 10     10    Kelechi       Osemele     1      70      76     307  OL     65
# 11     11       Ryan         Kalil     1      55      77     321  OL     62
# 12     12      Brian       Winters     1      67      76     320  OL     64
# 13     13    Brandon         Shell     1      72      77     297  OL     68
# 14     14    Leonard      Williams     5      92      76     315  DL     71
# 15     15      Steve      McLendon     5      99      77     302  DL     73
# 16     16    Quinnen      Williams     5      95      76     320  DL     62
# 17     17      Henry      Anderson     1      96      75     294  DL     70
# 18     18     Harvey         Langi     5      44      74     250  LB     75
# 19     19       C.J.        Mosley     5      57      74     240  LB     84
# 20     20    Neville        Hewitt     5      46      75     244  LB     77
# 21     21     Jordan       Jenkins     5      48      73     232  LB     90
# 22     22     Darryl       Roberts     5      27      71     198  DB     88
# 23     23      Brian         Poole     5      34      70     198  DB     88
# 24     24      Jamal         Adams     5      33      71     208  DB     86
# 25     25     Marcus          Maye     5      20      69     185  DB     91
# 26     26   Trumaine       Johnson     5      22      72     202  DB     85
# 27     27     Arthur        Maulet     5      23      72     201  DB     92
# 28     28        Sam        Ficken     1       9      73     222   K     68
# 29     29    Lachlan       Edwards     1       4      76     211   P     49
# 30     30   Jeremiah      Attaochu     5      51      75     259  LB     81
# 31     31    Neville        Hewitt     5      50      76     259  LB     77
# 32     32      Kevin  Pierre-Louis     1      53      77     225  LB     83
# 33     33    Charone         Peake     5      17      72     220  WR     81
# 34     34       Mike        Pennel     5      75      76     315  DL     72
# 35     35        Sam       Darnold     1      16      75     221  QB     70
# 36     36     Buster        Skrine     5      45      71     196  DB     86
# 37     37  Folorunso      Fatukasi     5      97      74     288  DL     75
# 38     38     Darryl       Roberts     5      23      72     211  DB     83
# 39     39    Frankie          Luvu     1      96      76     270  LB     79
# 40     40        Ray         Lucas     3       6      75     230  QB     77
# 41     41      Parry     Nickerson     5      30      70     196  DB     91
# 42     42     Elijah       McGuire     5      41      73     247  RB     75
# 43     43    Rashard      Robinson     1      47      72     212  DB     89
# 44     44      Brent         Qvale     1      69      79     318  OL     61
# 45     45      Chris       Herndon     5      84      79     260  TE     78
# 46     46     Jordan       Leggett     1      82      79     265  TE     81
# 47     47     Dakota        Dozier     5      65      76     312  OL     58
# 48     48  Jonotthan      Harrison     1      46      75     270  OL     66
# 49     49     Tarell        Basham     5      99      76     321  LB     68
# 50     50       Neal      Sterling     5      86      72     196  TE     92
# 51     51    Derrick         Jones     5      89      72     215  DB     88
# 52     52       Doug     Middleton     5      71      79     315  DB     65
#
#     TLK BRK  ...  HIT PWR  ENDUR  VISOR  SLEEVES  BANDS  WRAPS  AGE  \
# 0        45  ...       13     85      0        0      0      0   26
# 1        92  ...       20     92      1        0      0      1   25
# 2        84  ...       15     87      1        0      0      0   27
# 3        76  ...       12     91      1        0      0      1   26
# 4        62  ...       12     93      1        0      1      1   25
# 5        78  ...       25     94      1        0      0      0   25
# 6        70  ...       15     87      1        1      1      0   24
# 7        69  ...       25     90      1        0      1      0   28
# 8        69  ...       12     90      1        0      0      0   26
# 9        15  ...       20     93      0        0      0      1   33
# 10       12  ...       20     88      0        1      1      1   27
# 11       12  ...       20     81      1        0      1      0   28
# 12       12  ...       12     88      0        1      1      1   26
# 13       15  ...       20     85      0        0      0      1   26
# 14       15  ...       74     88      1        0      0      0   30
# 15       37  ...       81     73      1        0      0      1   30
# 16       10  ...       72     75      1        0      0      0   24
# 17       41  ...       78     83      1        0      0      0   27
# 18       33  ...       88     90      1        0      1      0   34
# 19       44  ...       90     92      0        0      0      1   25
# 20       25  ...       82     85      0        0      1      0   24
# 21       38  ...       79     87      1        0      0      0   29
# 22       64  ...       66     98      0        0      0      0   26
# 23       60  ...       55     95      1        1      0      0   29
# 24       61  ...       95     92      1        0      0      0   29
# 25       56  ...       41     91      1        1      1      1   25
# 26       57  ...       86     87      0        1      1      1   28
# 27       67  ...       77     96      0        0      0      1   27
# 28       21  ...       12     75      0        1      0      1   24
# 29       16  ...       19     68      0        1      0      0   38
# 30       36  ...       78     90      1        0      0      1   30
# 31       38  ...       81     85      0        1      0      1   22
# 32       25  ...       76     82      0        0      1      1   36
# 33       76  ...       20     87      0        0      0      1   31
# 34       17  ...       76     68      1        1      0      0   36
# 35       68  ...       12     95      0        0      1      1   35
# 36       37  ...       70     92      1        1      1      0   33
# 37       21  ...       75     78      0        0      1      0   27
# 38       54  ...       86     87      0        0      1      0   28
# 39       46  ...       76     82      0        0      0      1   23
# 40       51  ...        7     87      0        0      0      0   32
# 41       57  ...       73     90      1        0      0      1   30
# 42       65  ...       20     88      1        0      0      0   35
# 43       27  ...       54     80      0        0      1      0   24
# 44       15  ...       20     82      0        1      0      0   24
# 45       65  ...       15     85      0        1      0      0   28
# 46       58  ...       12     80      0        0      1      0   28
# 47       14  ...       25     82      1        0      0      0   36
# 48       45  ...       49     75      0        0      1      1   27
# 49       15  ...       71     69      1        0      0      0   25
# 50       71  ...       15     85      0        0      1      0   24
# 51       75  ...       12     85      0        1      0      0   23
# 52       12  ...       37     84      0        0      1      0   23
#
#     POTENTIAL  PORTRAIT  DISCIPLINE
# 0          89       276          99
# 1          96         8          57
# 2          91       157          91
# 3          99       183          69
# 4          93       297          78
# 5          82       171          53
# 6          78       316          79
# 7          79       149          92
# 8          87        88          64
# 9          90        19          74
# 10         77       128          87
# 11         94       133          92
# 12         87       284          72
# 13         77       225          52
# 14         77       279          86
# 15         80        71          90
# 16         79       153          95
# 17         84        64          89
# 18         75       174          93
# 19         81       242          60
# 20         91       238          86
# 21         96        60          76
# 22         95       305          96
# 23         79       106          99
# 24         70       185          55
# 25         92       311          74
# 26         73       104          77
# 27         79       121          70
# 28         82         6          79
# 29         92       219          59
# 30         84        93          99
# 31         99        43          80
# 32         85        72          60
# 33         81       277          53
# 34         75       231          68
# 35         91        94          59
# 36         91       289          79
# 37         80       263          76
# 38         80       144          73
# 39         86       164          70
# 40         71       164          93
# 41         83       327          74
# 42         83       132          98
# 43         85        28          97
# 44         67        30          89
# 45         87       281          89
# 46         93       107          78
# 47         66       306          85
# 48         87        80          60
# 49         91       150          57
# 50         91       198          62
# 51         79       308          92
# 52         80       325          78
#
# [53 rows x 33 columns]

# %% [markdown]
# ## Obtaining An NFL Team's New Axis Football Starting Offense Roster
#
# In the code cell below, we obtain an NFL team's new Axis Football starting offense roster. $\textbf{Note}:$ Each Axis roster must have exactly $14$ starters on offense, and they must be listed in the following order.
#
# * QB 1
# * RB 1
# * FB 1
# * WRs 1-5
# * TE 1
# * LT 1
# * LG 1
# * C 1
# * RG 1
# * RT 1
#
# $\textbf{Note}:$ Some teams may not have a FB. In that case, we replace FB 1 with RB 2.

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_offense_df) !=14:
        print("{} has {} players on offense".format(team_name, len(RG.axis_roster_starting_offense_df)))
        print(RG.madden_position_count_dict)
        
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_starting_offense_df
# Out:
# Las Vegas Raiders has 13 players on offense
# {'QB': 2, 'HB': 4, 'FB': 2, 'WR': 4, 'TE': 6, 'LT': 2, 'LG': 2, 'C': 2, 'RG': 4, 'RT': 1, 'LE': 2, 'DT': 6, 'RE': 3, 'LOLB': 3, 'MLB': 4, 'ROLB': 2, 'CB': 8, 'FS': 3, 'SS': 2, 'K': 1, 'P': 1}
#    firstName         lastName position  jerseyNum  age  height  weight  \
# 29      Zach           Wilson       QB          2   22      74     214
# 17   Michael           Carter       HB         32   22      68     201
# 55      Nick           Bawden       FB         48   25      74     245
# 9      Corey            Davis       WR         84   26      75     209
# 10   Jamison          Crowder       WR         82   28      69     177
# 11    Keelan          Cole Sr       WR         88   28      73     195
# 13    Elijah            Moore       WR          8   21      70     178
# 20   Braxton          Berrios       WR         10   25      69     186
# 31     Tyler            Kroft       TE         81   28      78     250
# 3      Mekhi           Becton       LT         77   22      79     364
# 19    Alijah      Vera-Tucker       LG         75   22      77     308
# 12    Connor         McGovern        C         60   28      76     306
# 16   Laurent  Duvernay-Tardif       RG         72   30      77     321
# 22    Morgan            Moses       RT         78   30      78     330
#
#     overall_rating  awareness_rating  strength_rating  ...  \
# 29              72                65               61  ...
# 17              75                73               66  ...
# 55              65                60               80  ...
# 9               78                79               72  ...
# 10              78                79               58  ...
# 11              77                79               67  ...
# 13              76                76               59  ...
# 20              74                73               53  ...
# 31              71                72               71  ...
# 3               82                89               94  ...
# 19              74                75               90  ...
# 12              76                85               87  ...
# 16              75                81               90  ...
# 22              74                83               89  ...
#
#     passBlockPower_rating  impactBlocking_rating  carrying_rating  \
# 29                     15                     21               66
# 17                     34                     34               91
# 55                     47                     66               72
# 9                      30                     62               70
# 10                     23                     45               74
# 11                     12                     51               73
# 13                     18                     41               76
# 20                     16                     39               72
# 31                     64                     64               76
# 3                      82                     99               40
# 19                     70                     88               35
# 12                     71                     81               33
# 16                     79                     84               65
# 22                     75                     85               45
#
#     breakTackle_rating  passBlock_rating  changeOfDirection_rating  \
# 29                  63                15                        80
# 17                  78                52                        91
# 55                  32                64                        73
# 9                   80                57                        86
# 10                  81                30                        93
# 11                  75                42                        80
# 13                  74                27                        93
# 20                  71                34                        88
# 31                  68                65                        66
# 3                   25                79                        55
# 19                   5                71                        50
# 12                  10                73                        54
# 16                   5                78                        54
# 22                   6                76                        46
#
#     press_rating  throwAccuracyDeep_rating runBlockFinesse_rating  \
# 29            10                        81                     12
# 17            16                        27                     24
# 55            10                        35                     55
# 9             17                        18                     35
# 10            15                        29                     11
# 11            15                        15                     25
# 13            18                        10                     32
# 20            10                         6                     10
# 31            25                         6                     55
# 3             10                         6                     85
# 19            10                         6                     79
# 12             8                         6                     83
# 16            10                         6                     73
# 22            10                         6                     79
#
#     agility_rating
# 29              84
# 17              89
# 55              78
# 9               91
# 10              94
# 11              90
# 13              92
# 20              91
# 31              76
# 3               59
# 19              61
# 12              69
# 16              68
# 22              56
#
# [14 rows x 62 columns]

# %% [markdown]
# ## Obtaining An NFL Team's New Axis Football Starting Defense Roster
# In the code cell below, we obtain an NFL team's new Axis Football starting defense roster. $\textbf{Note}:$ Each Axis Football roster must have exactly $14$ starters on defense. They must be listed in the following order.
#
# * LE 1, DTs 1-2, RE 1 (Total of 4 DLs; $\textbf{Note}:$ the distribution of positions may vary depending on team)
# * LOLB 1, MLBs 1-2, ROLB 1 (Total of 4 LBs; $\textbf{Note}:$ the distribution of positions may vary depending on team)
# * LCB 1, LCB 2, SS 1, FS 1, RCB 1, RCB 2 (Total of 6 DBs; $\textbf{Note}:$ the distribution may vary depending on team)

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_defense_df) !=14:
        print("{} has only {} players on defense".format(team_name, len(RG.axis_roster_starting_defense_df)))
        print(RG.madden_position_count_dict)
        
team_name="New York Jets"
RosterGenerator(team_name,week_num).axis_roster_starting_defense_df
# Out:
#     firstName        lastName position  jerseyNum  age  height  weight  \
# 5        John  Franklin-Myers       LE         91   24      76     292
# 0     Quinnen        Williams       DT         95   23      75     303
# 7   Folorunso        Fatukasi       DT         94   26      76     315
# 2        Carl          Lawson       RE         58   26      74     261
# 4        C.J.          Mosley     LOLB         57   29      74     231
# 34     Jarrad           Davis      MLB         52   25      73     245
# 52     Jamien        Sherwood      MLB         44   21      74     216
# 28      Blake         Cashman     ROLB         53   25      73     235
# 6       Bryce            Hall       CB         37   23      73     202
# 39    Javelin          Guidry       CB         40   23      69     191
# 1      Marcus            Maye       SS         20   28      72     207
# 15     Ashtyn           Davis       FS         21   24      73     202
# 35    Michael       Carter II       CB         30   22      70     184
# 46    Brandin          Echols       CB         26   23      70     175
#
#     overall_rating  awareness_rating  strength_rating  ...  \
# 5               81                86               90  ...
# 0               86                89               89  ...
# 7               79                82               90  ...
# 2               83                80               88  ...
# 4               81                81               75  ...
# 34              70                72               83  ...
# 52              65                66               65  ...
# 28              72                68               70  ...
# 6               79                84               57  ...
# 39              69                62               60  ...
# 1               85                87               77  ...
# 15              75                73               60  ...
# 35              70                68               55  ...
# 46              67                63               52  ...
#
#     passBlockPower_rating  impactBlocking_rating  carrying_rating  \
# 5                      45                     86               26
# 0                      44                     89               39
# 7                      45                     85               26
# 2                      45                     79               27
# 4                      45                     87               66
# 34                     45                     86               48
# 52                     35                     62               64
# 28                     45                     79               52
# 6                      35                     53               64
# 39                     35                     48               68
# 1                      35                     71               65
# 15                     33                     59               64
# 35                     35                     39               54
# 46                     35                     39               62
#
#     breakTackle_rating  passBlock_rating  changeOfDirection_rating  \
# 5                   24                45                        64
# 0                   16                44                        61
# 7                   10                45                        60
# 2                   31                45                        66
# 4                   32                45                        73
# 34                  10                45                        71
# 52                  54                35                        77
# 28                  12                45                        78
# 6                   48                35                        84
# 39                  44                40                        89
# 1                   42                35                        83
# 15                  61                30                        86
# 35                  39                35                        83
# 46                  45                35                        88
#
#     press_rating  throwAccuracyDeep_rating runBlockFinesse_rating  \
# 5             25                         9                     45
# 0             14                         6                     45
# 7             12                         6                     45
# 2             30                         6                     45
# 4             49                         6                     45
# 34            42                         6                     45
# 52            74                        29                     35
# 28            46                         6                     45
# 6             77                         6                     35
# 39            65                        10                     35
# 1             66                        10                     35
# 15            64                        14                     34
# 35            63                         6                     35
# 46            64                        12                     35
#
#     agility_rating
# 5               74
# 0               79
# 7               69
# 2               82
# 4               87
# 34              79
# 52              79
# 28              85
# 6               86
# 39              88
# 1               86
# 15              90
# 35              87
# 46              89
#
# [14 rows x 62 columns]

# %% [markdown]
# ## Obtaining An NFL Team's New Axis Football Starting Special Teams Roster
# In the code cell below, we obtain an NFL team's new Axis Football starting special teams roster. $\textbf{Note}:$ Each Axis Football roster must have $2$ starters on Special Teams. They must be listed in the following order.
# * K 1
# * P 1

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_ST_df) != 2:
        print("{} has only {} players on special teams".format(team_name, len(RG.axis_roster_starting_ST_df)))
        print(RG.madden_position_count_dict)
        
team_name="New York Jets"
RosterGenerator(team_name,week_num).axis_roster_starting_ST_df
# Out:
#    firstName lastName position  jerseyNum  age  height  weight  \
# 32      Eddy  Pineiro        K         15   25      71     185
# 24    Braden     Mann        P          7   23      71     198
#
#     overall_rating  awareness_rating  strength_rating  ...  \
# 32              70                56               42  ...
# 24              73                55               45  ...
#
#     passBlockPower_rating  impactBlocking_rating  carrying_rating  \
# 32                     17                     16               20
# 24                     24                     23               25
#
#     breakTackle_rating  passBlock_rating  changeOfDirection_rating  \
# 32                   5                17                        53
# 24                  20                20                        70
#
#     press_rating  throwAccuracyDeep_rating runBlockFinesse_rating  \
# 32            10                        12                     16
# 24            10                        15                     23
#
#     agility_rating
# 32              62
# 24              83
#
# [2 rows x 62 columns]

# %% [markdown]
# ## Obtaining An NFL Team's New Axis Football Backup Roster
#
# In the code cell below, we obtain an NFL team's Axis Football backup roster.
# $\textbf{Note}:$ Each Axis Football roster must consist of exactly $23$ players that are not starters.

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_backups_df) != 23:
        print("{} has only {} backup players".format(team_name, len(RG.axis_roster_backups_df)))
        print(RG.madden_position_count_dict)
        
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_backups_df
# Out:
#     firstName     lastName position  jerseyNum  age  height  weight  \
# 45        Joe       Flacco       QB         19   36      78     245
# 67       Mike        White       QB          5   26      77     218
# 26      Tevin      Coleman       HB         23   28      73     210
# 37         Ty      Johnson       HB         25   23      71     210
# 50   La'Mical       Perine       HB         22   23      71     216
# 63     Austin       Walter       HB         36   25      68     190
# 30     Denzel         Mims       WR         11   23      75     207
# 47       Jeff        Smith       WR         16   24      73     195
# 42       Ryan      Griffin       TE         86   31      78     255
# 58      Kenny       Yeboah       TE         83   22      76     250
# 14     George         Fant       LT         76   29      77     322
# 38        Dan       Feeney       LG         67   27      76     310
# 44       Greg    Van Roten       RG         62   31      75     303
# 43      Chuma        Edoga       RT         70   24      75     308
# 18      Vinny        Curry       LE         99   33      75     279
# 40       Kyle     Phillips       LE         93   24      76     273
# 23    Sheldon      Rankins       DT         98   27      74     305
# 36     Nathan     Shepherd       DT         97   27      76     315
# 21      Bryce         Huff       RE         47   23      75     255
# 25       Shaq       Lawson       RE         50   27      75     267
# 61  Del'Shawn     Phillips     LOLB         43   24      74     230
# 41     Quincy     Williams     ROLB         56   25      71     225
# 51     Hamsah  Nasirildeen     ROLB         45   22      75     215
#
#     overall_rating  awareness_rating  strength_rating  ...  \
# 45              68                68               68  ...
# 67              55                63               54  ...
# 26              73                71               69  ...
# 37              70                71               64  ...
# 50              66                71               75  ...
# 63              62                55               60  ...
# 30              71                70               69  ...
# 47              67                65               56  ...
# 42              69                71               72  ...
# 58              64                61               70  ...
# 14              76                85               85  ...
# 38              69                82               88  ...
# 44              68                83               84  ...
# 43              68                77               84  ...
# 18              75                79               81  ...
# 40              69                66               77  ...
# 23              74                82               88  ...
# 36              70                70               90  ...
# 21              74                73               72  ...
# 25              73                71               85  ...
# 61              63                56               72  ...
# 41              69                72               65  ...
# 51              65                64               67  ...
#
#     passBlockPower_rating  impactBlocking_rating  carrying_rating  \
# 45                     25                     30               59
# 67                     18                     20               57
# 26                     44                     39               85
# 37                     25                     31               87
# 50                     36                     46               90
# 63                     34                     33               82
# 30                     28                     48               73
# 47                     18                     40               72
# 42                     54                     66               73
# 58                     55                     64               76
# 14                     78                     80               61
# 38                     68                     84               23
# 44                     70                     79               29
# 43                     69                     79               24
# 18                     45                     80               40
# 40                     45                     75               40
# 23                     44                     83               40
# 36                     45                     84               36
# 21                     45                     77               40
# 25                     45                     78               26
# 61                     45                     72               58
# 41                     44                     69               44
# 51                     35                     73               62
#
#     breakTackle_rating  passBlock_rating  changeOfDirection_rating  \
# 45                  41                15                        65
# 67                  22                19                        72
# 26                  74                57                        87
# 37                  72                50                        85
# 50                  74                59                        80
# 63                  71                46                        82
# 30                  73                38                        78
# 47                  68                28                        90
# 42                  52                55                        65
# 58                  57                58                        74
# 14                  38                80                        57
# 38                   8                65                        51
# 44                   5                68                        53
# 43                   9                71                        56
# 18                  10                45                        64
# 40                  29                45                        64
# 23                  13                44                        61
# 36                  24                45                        62
# 21                  10                45                        72
# 25                  19                45                        65
# 61                  43                45                        71
# 41                  18                21                        73
# 51                  55                35                        80
#
#     press_rating  throwAccuracyDeep_rating runBlockFinesse_rating  \
# 45            10                        78                     20
# 67            10                        64                     18
# 26            10                        10                     34
# 37            15                        10                     23
# 50            26                        10                     30
# 63            20                        15                     28
# 30            26                        29                     30
# 47            15                        15                     22
# 42            10                         6                     64
# 58            34                         6                     57
# 14            10                         6                     78
# 38            15                         6                     69
# 44            10                         6                     75
# 43            10                         6                     74
# 18            18                         6                     45
# 40            40                         6                     45
# 23            13                         6                     45
# 36            13                         6                     45
# 21            33                         6                     45
# 25            22                         6                     45
# 61            46                         6                     45
# 41            50                         6                     44
# 51            77                        10                     35
#
#     agility_rating
# 45              66
# 67              71
# 26              91
# 37              86
# 50              81
# 63              88
# 30              92
# 47              88
# 42              80
# 58              82
# 14              75
# 38              67
# 44              61
# 43              70
# 18              79
# 40              75
# 23              74
# 36              76
# 21              80
# 25              77
# 61              78
# 41              78
# 51              82
#
# [23 rows x 62 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Roster for Gameplay
#
# In the code cell below, we update an NFL team's original Axis Football roster with the new starters and backup rosters we obtained. In updating, we need to convert between player attributes in Axis Football and player attributes in Madden NFL. We load a dictionary whose keys are Axis Football player attributes and corresponding values are (closest related) Madden NFL player attributes.
#
# We update an NFL team's original Axis Footall roster as follows. First, we concatenate the team's constructed starting and backup rosters from above. For each Axis Football player attribute, we replace the original Axis Footall roster column containing that attribute with the concatenated roster column containing the corresponding Madden attribute according to the dictionary.
#
# $\textbf{Note}:$ If an Axis Football attribute corresponds to a list of multiple Madden attributes, we replace the original Axis Footall roster column containing that attribute with the $\textbf{row-wise average}$ of the concatenated roster columns containing the Madden attributes.

# %%
print(axis_to_madden_attributes_dict)
print(" ")
for team_name in NFL_team_names:
    RosterGenerator(team_name,week_num).get_new_axis_roster_df()

team_name='New York Jets'
RosterGenerator(team_name,week_num).get_new_axis_roster_df()
# Out:
# {'FIRST': 'firstName', 'LAST': 'lastName', 'NUMBER': 'jerseyNum', 'HEIGHT': 'height', 'WEIGHT': 'weight', 'POS': 'position', 'SPEED': 'speed_rating', 'TLK BRK': 'breakTackle_rating', 'FUMBLE': 'carrying_rating', 'CATCH': ['catching_rating', 'spectacularCatch_rating', 'catchInTraffic_rating'], 'BLKING': ['runBlock_rating', 'passBlockFinesse_rating', 'leadBlock_rating', 'runBlockPower_rating', 'passBlockPower_rating', 'impactBlocking_rating', 'passBlock_rating', 'runBlockFinesse_rating'], 'THR ACC': ['throwAccuracyMid_rating', 'throwUnderPressure_rating', 'throwAccuracyShort_rating', 'throwOnTheRun_rating', 'throwAccuracyDeep_rating'], 'KCK PWR': 'kickPower_rating', 'KCK ACC': 'kickAccuracy_rating', 'BLK BRK': 'blockShedding_rating', 'TACKLE': 'tackle_rating', 'THR PWR': 'throwPower_rating', 'FITNESS': 'stamina_rating', 'AWARE': 'awareness_rating', 'AGIL': 'agility_rating', 'COVER': ['zoneCoverage_rating', 'manCoverage_rating'], 'HIT PWR': 'hitPower_rating', 'ENDUR': 'injury_rating', 'AGE': 'age'}
#     INDEX      FIRST             LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  \
# 0       0       Zach           Wilson     1       2      74     214  QB
# 1       1    Michael           Carter     5      32      68     201  RB
# 2       2       Nick           Bawden     5      48      74     245  RB
# 3       3      Corey            Davis     5      84      75     209  WR
# 4       4    Jamison          Crowder     1      82      69     177  WR
# 5       5     Keelan          Cole Sr     5      88      73     195  WR
# 6       6     Elijah            Moore     5       8      70     178  WR
# 7       7    Braxton          Berrios     5      10      69     186  WR
# 8       8      Tyler            Kroft     1      81      78     250  TE
# 9       9      Mekhi           Becton     1      77      79     364  OL
# 10     10     Alijah      Vera-Tucker     1      75      77     308  OL
# 11     11     Connor         McGovern     1      60      76     306  OL
# 12     12    Laurent  Duvernay-Tardif     1      72      77     321  OL
# 13     13     Morgan            Moses     1      78      78     330  OL
# 14     14       John   Franklin-Myers     5      91      76     292  DL
# 15     15    Quinnen         Williams     5      95      75     303  DL
# 16     16  Folorunso         Fatukasi     5      94      76     315  DL
# 17     17       Carl           Lawson     1      58      74     261  DL
# 18     18       C.J.           Mosley     5      57      74     231  LB
# 19     19     Jarrad            Davis     5      52      73     245  LB
# 20     20     Jamien         Sherwood     5      44      74     216  LB
# 21     21      Blake          Cashman     5      53      73     235  LB
# 22     22      Bryce             Hall     5      37      73     202  DB
# 23     23    Javelin           Guidry     5      40      69     191  DB
# 24     24     Marcus             Maye     5      20      72     207  DB
# 25     25     Ashtyn            Davis     5      21      73     202  DB
# 26     26    Michael        Carter II     5      30      70     184  DB
# 27     27    Brandin           Echols     5      26      70     175  DB
# 28     28       Eddy          Pineiro     1      15      71     185   K
# 29     29     Braden             Mann     1       7      71     198   P
# 30     30        Joe           Flacco     5      19      78     245  QB
# 31     31       Mike            White     5       5      77     218  QB
# 32     32      Tevin          Coleman     1      23      73     210  RB
# 33     33         Ty          Johnson     5      25      71     210  RB
# 34     34   La'Mical           Perine     5      22      71     216  RB
# 35     35     Austin           Walter     1      36      68     190  RB
# 36     36     Denzel             Mims     5      11      75     207  WR
# 37     37       Jeff            Smith     5      16      73     195  WR
# 38     38       Ryan          Griffin     5      86      78     255  TE
# 39     39      Kenny           Yeboah     1      83      76     250  TE
# 40     40     George             Fant     3      76      77     322  OL
# 41     41        Dan           Feeney     5      67      76     310  OL
# 42     42       Greg        Van Roten     5      62      75     303  OL
# 43     43      Chuma            Edoga     1      70      75     308  OL
# 44     44      Vinny            Curry     1      99      75     279  DL
# 45     45       Kyle         Phillips     5      93      76     273  DL
# 46     46    Sheldon          Rankins     1      98      74     305  DL
# 47     47     Nathan         Shepherd     5      97      76     315  DL
# 48     48      Bryce             Huff     1      47      75     255  DL
# 49     49       Shaq           Lawson     5      50      75     267  DL
# 50     50  Del'Shawn         Phillips     5      43      74     230  LB
# 51     51     Quincy         Williams     5      56      71     225  LB
# 52     52     Hamsah      Nasirildeen     5      45      75     215  LB
#
#     SPEED  TLK BRK  ...  HIT PWR  ENDUR  VISOR  SLEEVES  BANDS  WRAPS  AGE  \
# 0      83       63  ...       14     84      0        0      0      0   22
# 1      88       78  ...       22     87      1        0      0      1   22
# 2      82       32  ...       36     88      1        0      0      0   25
# 3      90       80  ...       27     86      1        0      0      1   26
# 4      89       81  ...       12     88      1        0      1      1   28
# 5      90       75  ...       18     95      1        0      0      0   28
# 6      92       74  ...       15     88      1        1      1      0   21
# 7      92       71  ...       15     82      1        0      1      0   25
# 8      79       68  ...       25     76      1        0      0      0   28
# 9      69       25  ...       20     83      0        0      0      1   22
# 10     68        5  ...       24     92      0        1      1      1   22
# 11     67       10  ...       25     90      1        0      1      0   28
# 12     70        5  ...       15     93      0        1      1      1   30
# 13     59        6  ...       20     89      0        0      0      1   30
# 14     79       24  ...       83     90      1        0      0      0   24
# 15     78       16  ...       84     91      1        0      0      1   23
# 16     63       10  ...       81     88      1        0      0      0   26
# 17     83       31  ...       76     76      1        0      0      0   26
# 18     83       32  ...       89     86      1        0      1      0   29
# 19     85       10  ...       87     83      0        0      0      1   25
# 20     82       54  ...       85     88      0        0      1      0   21
# 21     89       12  ...       83     76      1        0      0      0   25
# 22     88       48  ...       57     85      0        0      0      0   23
# 23     96       44  ...       50     90      1        1      0      0   23
# 24     90       42  ...       87     85      1        0      0      0   28
# 25     92       61  ...       82     85      1        1      1      1   24
# 26     93       39  ...       45     88      0        1      1      1   22
# 27     93       45  ...       47     86      0        0      0      1   23
# 28     78        5  ...       13     85      0        1      0      1   25
# 29     78       20  ...       12     86      0        1      0      0   23
# 30     71       41  ...       12     93      1        0      0      1   36
# 31     70       22  ...       12     94      0        1      0      1   26
# 32     91       74  ...       33     82      0        0      1      1   28
# 33     92       72  ...       28     88      0        0      0      1   23
# 34     85       74  ...       44     88      1        1      0      0   23
# 35     89       71  ...       22     91      0        0      1      1   25
# 36     92       73  ...       34     93      1        1      1      0   23
# 37     93       68  ...       22     90      0        0      1      0   24
# 38     72       52  ...       20     88      0        0      1      0   31
# 39     83       57  ...       31     88      0        0      0      1   22
# 40     76       38  ...       63     86      0        0      0      0   29
# 41     64        8  ...       38     90      1        0      0      1   27
# 42     64        5  ...       15     91      1        0      0      0   31
# 43     67        9  ...       35     83      0        0      1      0   24
# 44     78       10  ...       81     87      0        1      0      0   33
# 45     84       29  ...       79     86      0        1      0      0   24
# 46     70       13  ...       80     88      0        0      1      0   27
# 47     70       24  ...       78     90      1        0      0      0   27
# 48     83       10  ...       80     91      0        0      1      1   23
# 49     81       19  ...       83     84      1        0      0      0   27
# 50     85       43  ...       84     86      0        0      1      0   24
# 51     87       18  ...       87     85      0        1      0      0   25
# 52     87       55  ...       83     82      0        0      1      0   22
#
#     POTENTIAL  PORTRAIT  DISCIPLINE
# 0          89       276          99
# 1          96         8          57
# 2          91       157          91
# 3          99       183          69
# 4          93       297          78
# 5          82       171          53
# 6          78       316          79
# 7          79       149          92
# 8          87        88          64
# 9          90        19          74
# 10         77       128          87
# 11         94       133          92
# 12         87       284          72
# 13         77       225          52
# 14         77       279          86
# 15         80        71          90
# 16         79       153          95
# 17         84        64          89
# 18         75       174          93
# 19         81       242          60
# 20         91       238          86
# 21         96        60          76
# 22         95       305          96
# 23         79       106          99
# 24         70       185          55
# 25         92       311          74
# 26         73       104          77
# 27         79       121          70
# 28         82         6          79
# 29         92       219          59
# 30         84        93          99
# 31         99        43          80
# 32         85        72          60
# 33         81       277          53
# 34         75       231          68
# 35         91        94          59
# 36         91       289          79
# 37         80       263          76
# 38         80       144          73
# 39         86       164          70
# 40         71       164          93
# 41         83       327          74
# 42         83       132          98
# 43         85        28          97
# 44         67        30          89
# 45         87       281          89
# 46         93       107          78
# 47         66       306          85
# 48         87        80          60
# 49         91       150          57
# 50         91       198          62
# 51         79       308          92
# 52         80       325          78
#
# [53 rows x 33 columns]

# %% [markdown]
# # References
#
# * Discussion Thread about Axis Player Attributes: https://steamcommunity.com/app/932980/discussions/0/1739968490571334749/
# * Detailed information about Madden Player attributes: https://madden.fandom.com/wiki/Attributes
