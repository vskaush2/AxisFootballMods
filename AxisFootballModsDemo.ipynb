# %% [markdown]
# # Axis Football 2023 Roster Mods
#
# In this notebook, we replace the current football rosters in the Steam game Axis Football 2023 with the rosters from the [Madden NFL 23 database](https://www.ea.com/games/madden-nfl/player-ratings).
#
# **Note**: The Madden NFL database updates itself during the NFL season at the end of each week.

# %%
from RosterGenerator import *
week_num = "0" # Update this number at the end of each week during the NFL season

try:
    # !rm -r "Madden Rosters"
except:
    pass
# Out:
# rm: Madden Rosters: No such file or directory

# %% [markdown]
# ## Obtaining NFL Teams
#
# In the code cell below, we print the names of all the $32$ NFL teams.

# %%
with open('Madden_Team_IDs.json', 'r') as f:
    madden_IDs_dict = json.load(f)
    NFL_team_names = list(madden_IDs_dict.keys())
print(NFL_team_names)
# Out:
# ['Chicago Bears', 'Cincinnati Bengals', 'Buffalo Bills', 'Denver Broncos', 'Cleveland Browns', 'Tampa Bay Buccaneers', 'Arizona Cardinals', 'Los Angeles Chargers', 'Kansas City Chiefs', 'Indianapolis Colts', 'Dallas Cowboys', 'Miami Dolphins', 'Philadelphia Eagles', 'Atlanta Falcons', 'San Francisco 49ers', 'New York Giants', 'Jacksonville Jaguars', 'New York Jets', 'Detroit Lions', 'Green Bay Packers', 'Carolina Panthers', 'New England Patriots', 'Las Vegas Raiders', 'Los Angeles Rams', 'Baltimore Ravens', 'Washington Football Team', 'New Orleans Saints', 'Seattle Seahawks', 'Pittsburgh Steelers', 'Tennessee Titans', 'Minnesota Vikings', 'Houston Texans']

# %% [markdown]
# ## Loading An NFL Team's Current Madden NFL Roster
#
# In the code cell below, we obtain an NFL team's current Madden NFL Roster from the aforementioned database.

# %%
team_name='New York Jets'
RosterGenerator(team_name,week_num).madden_roster_df
# Out:
#    firstName  lastName position  jerseyNum  age  height  weight  \
# 0    Quinnen  Williams       DT         95   25      75     303
# 1      Sauce   Gardner       CB          1   23      75     200
# 2     Dalvin      Cook       HB         33   28      70     210
# 3      Aaron   Rodgers       QB          8   39      74     223
# 4       C.J.    Mosley      MLB         57   31      74     231
# ..       ...       ...      ...        ...  ...     ...     ...
# 56     Chazz   Surratt     LOLB         55   26      74     233
# 57      Nick    Bawden       FB         48   27      74     245
# 58     Irvin   Charles       WR         19   26      76     219
# 59     Kenny    Yeboah       TE         88   24      75     250
# 60    Thomas  Hennessy       TE         42   29      74     246
#
#     overall_rating  awareness_rating  throwPower_rating  ...  \
# 0               93                97                 23  ...
# 1               93                88                 27  ...
# 2               90                89                 40  ...
# 3               86                85                 93  ...
# 4               85                85                 25  ...
# ..             ...               ...                ...  ...
# 56              65                64                 67  ...
# 57              65                62                 54  ...
# 58              64                56                 27  ...
# 59              63                61                 29  ...
# 60              30                57                 38  ...
#
#     kickPower_rating  throwUnderPressure_rating  passBlock_rating  \
# 0                 17                         12                44
# 1                 17                         10                35
# 2                 17                         17                56
# 3                 15                         90                12
# 4                 20                         10                45
# ..               ...                        ...               ...
# 56                21                         48                45
# 57                18                         34                64
# 58                15                         16                37
# 59                70                         10                58
# 60                13                         10                59
#
#     changeOfDirection_rating  press_rating  throwAccuracyDeep_rating  \
# 0                         61            14                         6
# 1                         90            91                         6
# 2                         94            20                        25
# 3                         78            10                        86
# 4                         71            49                         6
# ..                       ...           ...                       ...
# 56                        73            40                        52
# 57                        71            10                        35
# 58                        78            26                        19
# 59                        74            32                         6
# 60                        68            15                         6
#
#     blockShedding_rating  runBlockFinesse_rating  agility_rating  \
# 0                     90                      45              79
# 1                     55                      35              90
# 2                     25                      32              93
# 3                     19                      18              80
# 4                     76                      45              86
# ..                   ...                     ...             ...
# 56                    61                      45              82
# 57                    43                      55              77
# 58                    27                      26              83
# 59                    40                      57              82
# 60                    48                      35              68
#
#     passBlockFinesse_rating
# 0                        45
# 1                        35
# 2                        28
# 3                        12
# 4                        45
# ..                      ...
# 56                       45
# 57                       42
# 58                       25
# 59                       59
# 60                       40
#
# [61 rows x 62 columns]

# %% [markdown]
# ## Loading An NFL Team's Initial Axis Football Roster
#
# In the code cell below, we obtain an NFL team's corresponding current, yet outdated, Axis Football roster.

# %%
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_df
# Out:
#     INDEX      FIRST          LAST  SKIN  NUMBER  HEIGHT  WEIGHT POS  SPEED  \
# 0       0       Luke          Falk     1       8      76     223  QB     86
# 1       1    Le'Veon          Bell     5      26      74     218  RB     96
# 2       2         Ty    Montgomery     5      88      70     204  RB     86
# 3       3    Jamison       Crowder     5      82      76     230  WR     84
# 4       4  Demaryius        Thomas     1      88      75     214  WR     82
# 5       5     Quincy        Enunwa     5      81      69     224  WR     86
# 6       6      Robby      Anderson     5      11      74     225  WR     90
# 7       7       Josh       Bellamy     5      15      66     195  WR     86
# 8       8       Ryan       Griffin     1      84      77     265  TE     85
# 9       9     Kelvin       Beachum     1      68      78     315  OL     62
# 10     10    Kelechi       Osemele     1      70      76     307  OL     65
# 11     11       Ryan         Kalil     1      55      77     321  OL     62
# 12     12      Brian       Winters     1      67      76     320  OL     64
# 13     13    Brandon         Shell     1      72      77     297  OL     68
# 14     14    Leonard      Williams     5      92      76     315  DL     71
# 15     15      Steve      McLendon     5      99      77     302  DL     73
# 16     16    Quinnen      Williams     5      95      76     320  DL     62
# 17     17      Henry      Anderson     1      96      75     294  DL     70
# 18     18     Harvey         Langi     5      44      74     250  LB     75
# 19     19       C.J.        Mosley     5      57      74     240  LB     84
# 20     20    Neville        Hewitt     5      46      75     244  LB     77
# 21     21     Jordan       Jenkins     5      48      73     232  LB     90
# 22     22     Darryl       Roberts     5      27      71     198  DB     88
# 23     23      Brian         Poole     5      34      70     198  DB     88
# 24     24      Jamal         Adams     5      33      71     208  DB     86
# 25     25     Marcus          Maye     5      20      69     185  DB     91
# 26     26   Trumaine       Johnson     5      22      72     202  DB     85
# 27     27     Arthur        Maulet     5      23      72     201  DB     92
# 28     28        Sam        Ficken     1       9      73     222   K     68
# 29     29    Lachlan       Edwards     1       4      76     211   P     49
# 30     30   Jeremiah      Attaochu     5      51      75     259  LB     81
# 31     31    Neville        Hewitt     5      50      76     259  LB     77
# 32     32      Kevin  Pierre-Louis     1      53      77     225  LB     83
# 33     33    Charone         Peake     5      17      72     220  WR     81
# 34     34       Mike        Pennel     5      75      76     315  DL     72
# 35     35        Sam       Darnold     1      16      75     221  QB     70
# 36     36     Buster        Skrine     5      45      71     196  DB     86
# 37     37  Folorunso      Fatukasi     5      97      74     288  DL     75
# 38     38     Darryl       Roberts     5      23      72     211  DB     83
# 39     39    Frankie          Luvu     1      96      76     270  LB     79
# 40     40        Ray         Lucas     3       6      75     230  QB     77
# 41     41      Parry     Nickerson     5      30      70     196  DB     91
# 42     42     Elijah       McGuire     5      41      73     247  RB     75
# 43     43    Rashard      Robinson     1      47      72     212  DB     89
# 44     44      Brent         Qvale     1      69      79     318  OL     61
# 45     45      Chris       Herndon     5      84      79     260  TE     78
# 46     46     Jordan       Leggett     1      82      79     265  TE     81
# 47     47     Dakota        Dozier     5      65      76     312  OL     58
# 48     48  Jonotthan      Harrison     1      46      75     270  OL     66
# 49     49     Tarell        Basham     5      99      76     321  LB     68
# 50     50       Neal      Sterling     5      86      72     196  TE     92
# 51     51    Derrick         Jones     5      89      72     215  DB     88
# 52     52       Doug     Middleton     5      71      79     315  DB     65
#
#     TLK BRK  ...  HIT PWR  ENDUR  VISOR  SLEEVES  BANDS  WRAPS  AGE  \
# 0        45  ...       13     85      0        0      0      0   26
# 1        92  ...       20     92      1        0      0      1   25
# 2        84  ...       15     87      1        0      0      0   27
# 3        76  ...       12     91      1        0      0      1   26
# 4        62  ...       12     93      1        0      1      1   25
# 5        78  ...       25     94      1        0      0      0   25
# 6        70  ...       15     87      1        1      1      0   24
# 7        69  ...       25     90      1        0      1      0   28
# 8        69  ...       12     90      1        0      0      0   26
# 9        15  ...       20     93      0        0      0      1   33
# 10       12  ...       20     88      0        1      1      1   27
# 11       12  ...       20     81      1        0      1      0   28
# 12       12  ...       12     88      0        1      1      1   26
# 13       15  ...       20     85      0        0      0      1   26
# 14       15  ...       74     88      1        0      0      0   30
# 15       37  ...       81     73      1        0      0      1   30
# 16       10  ...       72     75      1        0      0      0   24
# 17       41  ...       78     83      1        0      0      0   27
# 18       33  ...       88     90      1        0      1      0   34
# 19       44  ...       90     92      0        0      0      1   25
# 20       25  ...       82     85      0        0      1      0   24
# 21       38  ...       79     87      1        0      0      0   29
# 22       64  ...       66     98      0        0      0      0   26
# 23       60  ...       55     95      1        1      0      0   29
# 24       61  ...       95     92      1        0      0      0   29
# 25       56  ...       41     91      1        1      1      1   25
# 26       57  ...       86     87      0        1      1      1   28
# 27       67  ...       77     96      0        0      0      1   27
# 28       21  ...       12     75      0        1      0      1   24
# 29       16  ...       19     68      0        1      0      0   38
# 30       36  ...       78     90      1        0      0      1   30
# 31       38  ...       81     85      0        1      0      1   22
# 32       25  ...       76     82      0        0      1      1   36
# 33       76  ...       20     87      0        0      0      1   31
# 34       17  ...       76     68      1        1      0      0   36
# 35       68  ...       12     95      0        0      1      1   35
# 36       37  ...       70     92      1        1      1      0   33
# 37       21  ...       75     78      0        0      1      0   27
# 38       54  ...       86     87      0        0      1      0   28
# 39       46  ...       76     82      0        0      0      1   23
# 40       51  ...        7     87      0        0      0      0   32
# 41       57  ...       73     90      1        0      0      1   30
# 42       65  ...       20     88      1        0      0      0   35
# 43       27  ...       54     80      0        0      1      0   24
# 44       15  ...       20     82      0        1      0      0   24
# 45       65  ...       15     85      0        1      0      0   28
# 46       58  ...       12     80      0        0      1      0   28
# 47       14  ...       25     82      1        0      0      0   36
# 48       45  ...       49     75      0        0      1      1   27
# 49       15  ...       71     69      1        0      0      0   25
# 50       71  ...       15     85      0        0      1      0   24
# 51       75  ...       12     85      0        1      0      0   23
# 52       12  ...       37     84      0        0      1      0   23
#
#     POTENTIAL  PORTRAIT  DISCIPLINE
# 0          89       276          99
# 1          96         8          57
# 2          91       157          91
# 3          99       183          69
# 4          93       297          78
# 5          82       171          53
# 6          78       316          79
# 7          79       149          92
# 8          87        88          64
# 9          90        19          74
# 10         77       128          87
# 11         94       133          92
# 12         87       284          72
# 13         77       225          52
# 14         77       279          86
# 15         80        71          90
# 16         79       153          95
# 17         84        64          89
# 18         75       174          93
# 19         81       242          60
# 20         91       238          86
# 21         96        60          76
# 22         95       305          96
# 23         79       106          99
# 24         70       185          55
# 25         92       311          74
# 26         73       104          77
# 27         79       121          70
# 28         82         6          79
# 29         92       219          59
# 30         84        93          99
# 31         99        43          80
# 32         85        72          60
# 33         81       277          53
# 34         75       231          68
# 35         91        94          59
# 36         91       289          79
# 37         80       263          76
# 38         80       144          73
# 39         86       164          70
# 40         71       164          93
# 41         83       327          74
# 42         83       132          98
# 43         85        28          97
# 44         67        30          89
# 45         87       281          89
# 46         93       107          78
# 47         66       306          85
# 48         87        80          60
# 49         91       150          57
# 50         91       198          62
# 51         79       308          92
# 52         80       325          78
#
# [53 rows x 33 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Starting Offense
#
# In the code cell below, we update an NFL team's Axis Football starting offense. Each Axis roster must have exactly $14$ starters on offense. They must be listed in the following order:
#
# * QB 1
# * RB 1
# * FB 1
# * WRs 1-5
# * TE 1
# * LT 1
# * LG 1
# * C 1
# * RG 1
# * RT 1
#
# **Note**: The counts of each listed football position will vary by team. Modify appropriately.

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_offense_df) !=14:
        print("{} has {} players on offense".format(team_name, len(RG.axis_roster_starting_offense_df)))
        print(RG.madden_position_count_dict)
        
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_starting_offense_df
# Out:
# Philadelphia Eagles has 13 players on offense
# {'QB': 3, 'HB': 4, 'FB': 0, 'WR': 4, 'TE': 5, 'LT': 3, 'LG': 2, 'C': 1, 'RG': 2, 'RT': 2, 'LE': 1, 'DT': 7, 'RE': 2, 'LOLB': 3, 'MLB': 2, 'ROLB': 2, 'CB': 9, 'FS': 2, 'SS': 2, 'K': 1, 'P': 1}
#    firstName     lastName position  jerseyNum  age  height  weight  \
# 3      Aaron      Rodgers       QB          8   39      74     223
# 2     Dalvin         Cook       HB         33   28      70     210
# 57      Nick       Bawden       FB         48   27      74     245
# 5    Garrett       Wilson       WR         17   23      72     192
# 15    Mecole   Hardman Jr       WR          6   25      70     187
# 17     Allen       Lazard       WR         10   27      77     227
# 26   Randall         Cobb       WR         18   33      70     192
# 45     Jason     Brownlee       WR         16   24      74     198
# 19     Tyler      Conklin       TE         83   28      75     254
# 24     Duane        Brown       LT         76   38      76     329
# 14     Laken    Tomlinson       LG         78   31      75     323
# 22    Connor     McGovern        C         60   30      76     306
# 11    Alijah  Vera-Tucker       RG         75   24      77     308
# 27     Mekhi    Becton Sr       RT         77   24      79     363
#
#     overall_rating  awareness_rating  throwPower_rating  ...  \
# 3               86                85                 93  ...
# 2               90                89                 40  ...
# 57              65                62                 54  ...
# 5               84                84                 26  ...
# 15              79                75                 56  ...
# 17              78                84                 21  ...
# 26              76                78                 64  ...
# 45              67                55                 30  ...
# 19              78                80                 30  ...
# 24              76                87                 78  ...
# 14              79                90                 20  ...
# 22              77                87                 21  ...
# 11              79                82                 25  ...
# 27              75                69                 25  ...
#
#     kickPower_rating  throwUnderPressure_rating  passBlock_rating  \
# 3                 15                         90                12
# 2                 17                         17                56
# 57                18                         34                64
# 5                 17                         15                30
# 15                44                         29                23
# 17                18                         19                45
# 26                35                         47                45
# 45                14                         27                35
# 19                19                         14                57
# 24                25                         16                81
# 14                20                         14                82
# 22                20                         12                75
# 11                20                         16                76
# 27                20                         15                71
#
#     changeOfDirection_rating  press_rating  throwAccuracyDeep_rating  \
# 3                         78            10                        86
# 2                         94            20                        25
# 57                        71            10                        35
# 5                         93            14                        12
# 15                        86            41                        37
# 17                        79            15                         6
# 26                        81            18                        35
# 45                        81            18                        12
# 19                        77            10                        10
# 24                        55            15                         6
# 14                        50            10                         6
# 22                        52             8                         6
# 11                        55            10                         6
# 27                        54            10                         6
#
#     blockShedding_rating  runBlockFinesse_rating  agility_rating  \
# 3                     19                      18              80
# 2                     25                      32              93
# 57                    43                      55              77
# 5                     20                      26              93
# 15                    41                      11              92
# 17                    40                      27              82
# 26                    35                      29              87
# 45                    26                      26              86
# 19                    24                      60              79
# 24                    30                      73              59
# 14                    20                      78              58
# 22                    27                      84              65
# 11                    25                      84              61
# 27                    31                      85              55
#
#     passBlockFinesse_rating
# 3                        12
# 2                        28
# 57                       42
# 5                        21
# 15                       10
# 17                       20
# 26                       17
# 45                       20
# 19                       54
# 24                       80
# 14                       81
# 22                       76
# 11                       76
# 27                       65
#
# [14 rows x 62 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Starting Defense
#
# In the code cell below, we update an NFL team's Axis Football starting offense. Each Axis roster must have exactly $14$ starters on defense. They must be listed in the following order:
#
# * LE 1
# * DTs 1-2
# * RE 1
# * LOLB 1
# * MLBs 1-2
# * ROLB 1
# * LCB 1
# * FS 1
# * SS 1
# * RCB 1
# * LCB 2
# * RCB 2
#
# **Note**: The counts of each listed football position will vary by team. Modify appropriately.

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_defense_df) !=14:
        print("{} has only {} players on defense".format(team_name, len(RG.axis_roster_starting_defense_df)))
        print(RG.madden_position_count_dict)
        
team_name="New York Jets"
RosterGenerator(team_name,week_num).axis_roster_starting_defense_df
# Out:
# Kansas City Chiefs has only 13 players on defense
# {'QB': 2, 'HB': 3, 'FB': 0, 'WR': 7, 'TE': 5, 'LT': 3, 'LG': 2, 'C': 1, 'RG': 2, 'RT': 2, 'LE': 2, 'DT': 5, 'RE': 4, 'LOLB': 0, 'MLB': 3, 'ROLB': 3, 'CB': 6, 'FS': 2, 'SS': 3, 'K': 1, 'P': 1}
# Green Bay Packers has only 13 players on defense
# {'QB': 2, 'HB': 3, 'FB': 0, 'WR': 6, 'TE': 6, 'LT': 4, 'LG': 2, 'C': 1, 'RG': 2, 'RT': 2, 'LE': 3, 'DT': 0, 'RE': 2, 'LOLB': 3, 'MLB': 4, 'ROLB': 3, 'CB': 5, 'FS': 3, 'SS': 3, 'K': 1, 'P': 1}
#    firstName        lastName position  jerseyNum  age  height  weight  \
# 8       John  Franklin-Myers       LE         91   26      76     288
# 0    Quinnen        Williams       DT         95   25      75     303
# 20        Al           Woods       DT         96   36      76     309
# 10      Carl          Lawson       RE         58   28      74     265
# 52    Jamien        Sherwood     LOLB         44   23      74     216
# 4       C.J.          Mosley      MLB         57   31      74     231
# 55     Zaire          Barnes      MLB         53   23      73     232
# 35    Quincy        Williams     ROLB         56   27      71     225
# 1      Sauce         Gardner       CB          1   23      75     200
# 13    Jordan       Whitehead       FS          3   26      70     198
# 6     Adrian            Amos       SS          0   30      72     214
# 7       D.J.         Reed Jr       CB          4   26      69     188
# 18     Bryce            Hall       CB         37   25      73     202
# 29   Michael       Carter II       CB         30   24      70     184
#
#     overall_rating  awareness_rating  throwPower_rating  ...  \
# 8               83                87                 20  ...
# 0               93                97                 23  ...
# 20              77                78                 20  ...
# 10              80                84                 12  ...
# 52              66                68                 43  ...
# 4               85                85                 25  ...
# 55              66                59                 28  ...
# 35              71                73                 25  ...
# 1               93                88                 27  ...
# 13              79                86                 24  ...
# 6               83                88                 30  ...
# 7               83                85                 22  ...
# 18              78                80                 35  ...
# 29              75                75                 27  ...
#
#     kickPower_rating  throwUnderPressure_rating  passBlock_rating  \
# 8                 16                         17                45
# 0                 17                         12                44
# 20                19                         14                45
# 10                14                         12                45
# 52                25                         29                35
# 4                 20                         10                45
# 55                18                         14                45
# 35                19                         13                21
# 1                 17                         10                35
# 13                13                         18                45
# 6                 25                         17                35
# 7                 14                         12                35
# 18                15                         12                35
# 29                18                         10                35
#
#     changeOfDirection_rating  press_rating  throwAccuracyDeep_rating  \
# 8                         63            25                         9
# 0                         61            14                         6
# 20                        52            12                         6
# 10                        67            30                         6
# 52                        76            74                        29
# 4                         71            49                         6
# 55                        78            48                        18
# 35                        73            50                         6
# 1                         90            91                         6
# 13                        80            70                         6
# 6                         85            77                        10
# 7                         90            87                         5
# 18                        84            87                         6
# 29                        83            67                         6
#
#     blockShedding_rating  runBlockFinesse_rating  agility_rating  \
# 8                     81                      45              72
# 0                     90                      45              79
# 20                    80                      45              64
# 10                    69                      45              80
# 52                    62                      35              79
# 4                     76                      45              86
# 55                    62                      45              83
# 35                    65                      44              78
# 1                     55                      35              90
# 13                    57                      35              81
# 6                     65                      35              81
# 7                     55                      35              88
# 18                    52                      35              86
# 29                    47                      35              87
#
#     passBlockFinesse_rating
# 8                        45
# 0                        45
# 20                       45
# 10                       45
# 52                       35
# 4                        45
# 55                       45
# 35                       43
# 1                        35
# 13                       35
# 6                        35
# 7                        35
# 18                       35
# 29                       35
#
# [14 rows x 62 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Starting Special Teams
# In the code cell below, we update an NFL team's Axis Football starting special teams. Each Axis Football roster must have $2$ starters on Special Teams. They must be listed in the following order:
# * K 1
# * P 1

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_starting_ST_df) != 2:
        print("{} has only {} players on special teams".format(team_name, len(RG.axis_roster_starting_ST_df)))
        print(RG.madden_position_count_dict)
        

RosterGenerator(team_name,week_num).axis_roster_starting_ST_df
# Out:
#    firstName   lastName position  jerseyNum  age  height  weight  \
# 7     Ka'imi  Fairbairn        K         15   29      72     183
# 15   Cameron   Johnston        P         11   31      71     194
#
#     overall_rating  awareness_rating  throwPower_rating  ...  \
# 7               79                64                 39  ...
# 15              75                58                 28  ...
#
#     kickPower_rating  throwUnderPressure_rating  passBlock_rating  \
# 7                 96                         15                15
# 15                95                         14                20
#
#     changeOfDirection_rating  press_rating  throwAccuracyDeep_rating  \
# 7                         53            10                        25
# 15                        54            10                        15
#
#     blockShedding_rating  runBlockFinesse_rating  agility_rating  \
# 7                     13                      17              64
# 15                    26                      23              62
#
#     passBlockFinesse_rating
# 7                        15
# 15                       24
#
# [2 rows x 62 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Backup Roster
#
# In the code cell below, we update an NFL team's Axis Football backup roster. Each Axis Football backup roster must consist of exactly $23$ players that are not starters.

# %%
for team_name in NFL_team_names:
    RG=RosterGenerator(team_name,week_num)
    if len(RG.axis_roster_backups_df) != 23:
        print("{} has only {} backup players".format(team_name, len(RG.axis_roster_backups_df)))
        print(RG.madden_position_count_dict)
        print(sum(RG.madden_position_count_dict.values()))
        
team_name='New York Jets'
RosterGenerator(team_name,week_num).axis_roster_backups_df
# Out:
# Chicago Bears has only 21 backup players
# {'QB': 3, 'HB': 4, 'FB': 1, 'WR': 7, 'TE': 4, 'LT': 2, 'LG': 3, 'C': 3, 'RG': 1, 'RT': 1, 'LE': 3, 'DT': 4, 'RE': 2, 'LOLB': 2, 'MLB': 2, 'ROLB': 1, 'CB': 6, 'FS': 2, 'SS': 2, 'K': 1, 'P': 1}
# 55
# Tampa Bay Buccaneers has only 22 backup players
# {'QB': 2, 'HB': 4, 'FB': 0, 'WR': 6, 'TE': 5, 'LT': 1, 'LG': 3, 'C': 2, 'RG': 2, 'RT': 2, 'LE': 2, 'DT': 2, 'RE': 2, 'LOLB': 3, 'MLB': 4, 'ROLB': 3, 'CB': 6, 'FS': 2, 'SS': 2, 'K': 1, 'P': 1}
# 55
# Green Bay Packers has only 22 backup players
# {'QB': 2, 'HB': 3, 'FB': 0, 'WR': 6, 'TE': 6, 'LT': 4, 'LG': 2, 'C': 1, 'RG': 2, 'RT': 2, 'LE': 3, 'DT': 0, 'RE': 2, 'LOLB': 3, 'MLB': 4, 'ROLB': 3, 'CB': 5, 'FS': 3, 'SS': 3, 'K': 1, 'P': 1}
# 56
# Carolina Panthers has only 22 backup players
# {'QB': 2, 'HB': 3, 'FB': 1, 'WR': 6, 'TE': 5, 'LT': 2, 'LG': 2, 'C': 2, 'RG': 3, 'RT': 1, 'LE': 2, 'DT': 2, 'RE': 2, 'LOLB': 3, 'MLB': 3, 'ROLB': 4, 'CB': 6, 'FS': 2, 'SS': 2, 'K': 1, 'P': 1}
# 55
# Los Angeles Rams has only 21 backup players
# {'QB': 2, 'HB': 4, 'FB': 0, 'WR': 6, 'TE': 5, 'LT': 2, 'LG': 1, 'C': 2, 'RG': 3, 'RT': 2, 'LE': 2, 'DT': 2, 'RE': 3, 'LOLB': 3, 'MLB': 3, 'ROLB': 2, 'CB': 5, 'FS': 3, 'SS': 2, 'K': 1, 'P': 1}
# 54
# New Orleans Saints has only 22 backup players
# {'QB': 3, 'HB': 5, 'FB': 1, 'WR': 6, 'TE': 5, 'LT': 2, 'LG': 2, 'C': 2, 'RG': 3, 'RT': 1, 'LE': 2, 'DT': 4, 'RE': 3, 'LOLB': 1, 'MLB': 2, 'ROLB': 3, 'CB': 5, 'FS': 3, 'SS': 2, 'K': 1, 'P': 1}
# 57
# Minnesota Vikings has only 22 backup players
# {'QB': 3, 'HB': 4, 'FB': 1, 'WR': 5, 'TE': 5, 'LT': 1, 'LG': 2, 'C': 2, 'RG': 2, 'RT': 3, 'LE': 2, 'DT': 2, 'RE': 2, 'LOLB': 3, 'MLB': 4, 'ROLB': 2, 'CB': 5, 'FS': 3, 'SS': 3, 'K': 1, 'P': 1}
# 56
#    firstName          lastName position  jerseyNum  age  height  weight  \
# 43      Zach            Wilson       QB          2   24      74     214
# 9     Breece              Hall       HB         20   22      73     220
# 28   Michael            Carter       HB         32   24      68     201
# 48    Xavier            Gipson       WR         82   22      70     189
# 58     Irvin           Charles       WR         19   26      76     219
# 23      C.J.            Uzomah       TE         87   30      77     271
# 46    Jeremy           Ruckert       TE         89   23      77     250
# 47       Max          Mitchell       LT         61   23      78     299
# 34       Joe          Tippmann        C         66   22      78     317
# 39       Wes        Schweitzer       RG         71   29      76     300
# 40     Billy            Turner       RT         54   31      77     313
# 21     Bryce              Huff       LE         47   25      75     255
# 37   Micheal           Clemons       LE         72   26      77     281
# 33   Quinton         Jefferson       DT         70   30      76     291
# 36   Solomon            Thomas       DT         94   28      74     256
# 31      Will       McDonald IV       RE         99   24      75     241
# 32  Jermaine        Johnson II       RE         11   24      77     262
# 41    Ifeadi          Odenigbo       RE         92   29      75     258
# 49   Bradlee              Anae       RE         50   25      75     260
# 56     Chazz           Surratt     LOLB         55   26      74     233
# 51    Hamsah       Nasirildeen     ROLB         45   24      75     215
# 44   Brandin            Echols       CB         26   25      70     175
# 53   Jarrick  Bernard-Converse       CB         29   23      73     197
#
#     overall_rating  awareness_rating  throwPower_rating  ...  \
# 43              69                64                 93  ...
# 9               82                78                 32  ...
# 28              75                73                 39  ...
# 48              67                52                 34  ...
# 58              64                56                 27  ...
# 23              76                75                 49  ...
# 46              67                68                 30  ...
# 47              67                75                 24  ...
# 34              71                75                 11  ...
# 39              70                79                 25  ...
# 40              69                79                 11  ...
# 21              77                78                 28  ...
# 37              70                69                 23  ...
# 33              73                84                 10  ...
# 36              71                65                 18  ...
# 31              74                72                 44  ...
# 32              73                64                 21  ...
# 41              69                68                 28  ...
# 49              66                71                 27  ...
# 56              65                64                 67  ...
# 51              66                66                 27  ...
# 44              68                63                 32  ...
# 53              66                59                 25  ...
#
#     kickPower_rating  throwUnderPressure_rating  passBlock_rating  \
# 43                57                         74                15
# 9                 18                         19                56
# 28                20                         21                51
# 48                16                         15                26
# 58                15                         16                37
# 23                22                         28                58
# 46                28                         10                60
# 47                22                         10                72
# 34                15                         10                72
# 39                18                         12                72
# 40                15                         12                73
# 21                15                         12                45
# 37                15                         12                45
# 33                21                         10                44
# 36                16                         17                45
# 31                35                         11                45
# 32                17                         10                45
# 41                15                         10                45
# 49                15                         17                45
# 56                21                         48                45
# 51                18                         13                35
# 44                21                         13                35
# 53                18                         22                25
#
#     changeOfDirection_rating  press_rating  throwAccuracyDeep_rating  \
# 43                        80            10                        80
# 9                         91            16                        12
# 28                        91            16                        27
# 48                        92            30                         6
# 58                        78            26                        19
# 23                        65            10                        34
# 46                        69            16                        14
# 47                        58            10                         5
# 34                        57            10                         6
# 39                        52            10                         6
# 40                        49            10                         6
# 21                        72            33                         6
# 37                        65            26                        10
# 33                        62            25                         6
# 36                        60            34                         6
# 31                        80            52                        22
# 32                        70            26                         6
# 41                        58            37                         6
# 49                        67            23                         6
# 56                        73            40                        52
# 51                        80            77                        10
# 44                        88            77                        12
# 53                        82            74                        20
#
#     blockShedding_rating  runBlockFinesse_rating  agility_rating  \
# 43                    22                      12              84
# 9                     29                      35              90
# 28                    24                      24              89
# 48                    38                      25              87
# 58                    27                      26              83
# 23                    49                      59              76
# 46                    36                      63              74
# 47                    25                      74              55
# 34                    25                      75              65
# 39                    29                      78              56
# 40                    25                      76              55
# 21                    62                      45              80
# 37                    78                      45              74
# 33                    71                      45              63
# 36                    69                      45              79
# 31                    65                      45              88
# 32                    77                      45              83
# 41                    67                      45              72
# 49                    64                      45              73
# 56                    61                      45              82
# 51                    66                      35              82
# 44                    43                      35              89
# 53                    50                      34              85
#
#     passBlockFinesse_rating
# 43                       15
# 9                        33
# 28                       38
# 48                       20
# 58                       25
# 23                       55
# 46                       58
# 47                       74
# 34                       69
# 39                       70
# 40                       75
# 21                       45
# 37                       45
# 33                       45
# 36                       45
# 31                       45
# 32                       45
# 41                       45
# 49                       45
# 56                       45
# 51                       35
# 44                       35
# 53                       25
#
# [23 rows x 62 columns]

# %% [markdown]
# ## Updating An NFL Team's Axis Football Player Attributes
#
# In the code cell below, we update each NFL team's Axis Football Player Attributes. We use a reference attribute dictionary in which each key is an Axis Football attribute and the corresponding value is the set of possible Madden NFL attributes that are similarly related to the key. So for each player, we apply the following procedure:
#    * If an Axis Football attribute has only one corresponding Madden NFL attribute in the reference dictionary, we update the player's Axis Football attribute with the player's corresponding Madden NFL attribute.
#    * If an Axis Football attribute has more than one corresponding Madden NFL attribute in the reference dictionary, we update the player's Axis Football attribute with the *average* of the player's corresponding Madden NFL attributes.

# %%
print(axis_to_madden_attributes_dict)
print(" ")
for team_name in NFL_team_names:
    RosterGenerator(team_name,week_num).get_new_axis_roster_df()
# Out:
# {'FIRST': 'firstName', 'LAST': 'lastName', 'NUMBER': 'jerseyNum', 'HEIGHT': 'height', 'WEIGHT': 'weight', 'POS': 'position', 'SPEED': 'speed_rating', 'TLK BRK': 'breakTackle_rating', 'FUMBLE': 'carrying_rating', 'CATCH': ['catching_rating', 'spectacularCatch_rating', 'catchInTraffic_rating'], 'BLKING': ['runBlock_rating', 'passBlockFinesse_rating', 'leadBlock_rating', 'runBlockPower_rating', 'passBlockPower_rating', 'impactBlocking_rating', 'passBlock_rating', 'runBlockFinesse_rating'], 'THR ACC': ['throwAccuracyMid_rating', 'throwUnderPressure_rating', 'throwAccuracyShort_rating', 'throwOnTheRun_rating', 'throwAccuracyDeep_rating'], 'KCK PWR': 'kickPower_rating', 'KCK ACC': 'kickAccuracy_rating', 'BLK BRK': 'blockShedding_rating', 'TACKLE': 'tackle_rating', 'THR PWR': 'throwPower_rating', 'FITNESS': 'stamina_rating', 'AWARE': 'awareness_rating', 'AGIL': 'agility_rating', 'COVER': ['zoneCoverage_rating', 'manCoverage_rating'], 'HIT PWR': 'hitPower_rating', 'ENDUR': 'injury_rating', 'AGE': 'age'}
#
# REVERTED TO EARLIER AXIS ROSTER FOR Chicago Bears
# REVERTED TO EARLIER AXIS ROSTER FOR Tampa Bay Buccaneers
# REVERTED TO EARLIER AXIS ROSTER FOR Kansas City Chiefs
# REVERTED TO EARLIER AXIS ROSTER FOR Philadelphia Eagles
# REVERTED TO EARLIER AXIS ROSTER FOR Green Bay Packers
# REVERTED TO EARLIER AXIS ROSTER FOR Carolina Panthers
# REVERTED TO EARLIER AXIS ROSTER FOR Los Angeles Rams
# REVERTED TO EARLIER AXIS ROSTER FOR New Orleans Saints
# REVERTED TO EARLIER AXIS ROSTER FOR Minnesota Vikings

# %% [markdown]
# Follow the instructions of the Readme in order to load these updated rosters into Axis Football game!

# %% [markdown]
# # References
#
# * [Discussion Thread about Axis Player Attributes](https://steamcommunity.com/app/932980/discussions/0/1739968490571334749/)
# * [Detailed information about Madden NFL attributes](https://madden.fandom.com/wiki/Attributes)
